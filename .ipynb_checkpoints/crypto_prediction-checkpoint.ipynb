# %%
import pandas as pd
import numpy as np
import pandas_datareader as web
import matplotlib.pyplot as plt
import datetime as dt

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
crypto_currency = 'ETH'
against_currency = 'USD'

start = dt.datetime(2016,1,1)
end = dt.datetime(2020,1,1)

# %%
data = web.DataReader(f'{crypto_currency}-{against_currency}','yahoo',start,end)

# %%
#Prepare data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data['Close'].values.reshape(-1,1))

prediction_days = 60

x_train=[]
y_train=[]

for x in range(prediction_days,len(scaled_data)):
    x_train.append(scaled_data[x-prediction_days:x,0])
    y_train.append(scaled_data[x,0])
    
x_train,y_train=np.array(x_train),np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

# %%
#Building the model

model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=100)) #Predition/Closing Value
model.add(Dense(units=1))


model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train,y_train,epochs=25,batch_size=32)
# Out:
# Epoch 1/25
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0076
# Epoch 2/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0023
# Epoch 3/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0019
# Epoch 4/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0018
# Epoch 5/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0020
# Epoch 6/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0016
# Epoch 7/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0018
# Epoch 8/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0016
# Epoch 9/25
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0016
# Epoch 10/25
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0017
# Epoch 11/25
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 12/25
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0014
# Epoch 13/25
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 14/25
# 44/44 [==============================] - 2s 42ms/step - loss: 0.0016
# Epoch 15/25
# 44/44 [==============================] - 2s 42ms/step - loss: 0.0015
# Epoch 16/25
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 17/25
# 44/44 [==============================] - 2s 42ms/step - loss: 0.0013
# Epoch 18/25
# 44/44 [==============================] - 2s 41ms/step - loss: 0.0012
# Epoch 19/25
# 44/44 [==============================] - 2s 40ms/step - loss: 9.7380e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 43ms/step - loss: 0.0010
# Epoch 21/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0013
# Epoch 22/25
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0011
# Epoch 23/25
# 44/44 [==============================] - 2s 45ms/step - loss: 9.0893e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 44ms/step - loss: 8.8450e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 45ms/step - loss: 0.0011

# %%
#TEST

test_start = dt.datetime(2020,1,1)
test_end = dt.datetime.now()

test_data = web.DataReader(f'{crypto_currency}-{against_currency}','yahoo',test_start,test_end)
actual_prices = test_data['Close'].values

total_dataset = pd.concat((data['Close'],test_data['Close']),axis=0)

#Unseen Data = Test Data 
model_inputs = total_dataset[len(total_dataset)-len(test_data)-prediction_days:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler.transform(model_inputs)

#Model Predicions

x_test = []

for x in range(prediction_days,len(model_inputs)):
    x_test.append(scaled_data[x-prediction_days:x,0])

x_test = np.array(x_test)    
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))  

pred_prices = model.predict(x_test)
pred_prices = scaler.inverse_transform(pred_prices)

# %%
pred_prices
# Out:
# array([[ 12.913341 ],
#        [ 13.107712 ],
#        [ 13.469687 ],
#        [ 14.018485 ],
#        [ 14.75957  ],
#        [ 15.612083 ],
#        [ 16.459946 ],
#        [ 16.962223 ],
#        [ 17.11525  ],
#        [ 17.257421 ],
#        [ 17.401377 ],
#        [ 17.502542 ],
#        [ 17.833433 ],
#        [ 18.464653 ],
#        [ 19.00522  ],
#        [ 19.377258 ],
#        [ 19.52114  ],
#        [ 19.315414 ],
#        [ 18.858862 ],
#        [ 18.264181 ],
#        [ 17.653416 ],
#        [ 17.314949 ],
#        [ 17.209461 ],
#        [ 17.390192 ],
#        [ 17.620699 ],
#        [ 17.73539  ],
#        [ 17.743982 ],
#        [ 17.622255 ],
#        [ 17.564905 ],
#        [ 17.60987  ],
#        [ 17.759008 ],
#        [ 17.895298 ],
#        [ 18.003418 ],
#        [ 18.069115 ],
#        [ 18.096804 ],
#        [ 18.043447 ],
#        [ 17.84668  ],
#        [ 17.588694 ],
#        [ 17.272575 ],
#        [ 16.914213 ],
#        [ 16.508564 ],
#        [ 16.093006 ],
#        [ 15.696972 ],
#        [ 15.230286 ],
#        [ 14.815829 ],
#        [ 14.560562 ],
#        [ 14.453783 ],
#        [ 14.496901 ],
#        [ 14.716413 ],
#        [ 15.003835 ],
#        [ 15.234836 ],
#        [ 15.338436 ],
#        [ 15.283768 ],
#        [ 15.088723 ],
#        [ 14.881543 ],
#        [ 14.691015 ],
#        [ 14.487708 ],
#        [ 14.27226  ],
#        [ 14.116321 ],
#        [ 13.97103  ],
#        [ 13.868657 ],
#        [ 13.973621 ],
#        [ 14.254661 ],
#        [ 14.761787 ],
#        [ 15.276527 ],
#        [ 15.686169 ],
#        [ 15.996393 ],
#        [ 16.151215 ],
#        [ 16.170506 ],
#        [ 16.11527  ],
#        [ 16.011326 ],
#        [ 15.900187 ],
#        [ 15.881562 ],
#        [ 15.961512 ],
#        [ 16.150686 ],
#        [ 16.363438 ],
#        [ 16.511786 ],
#        [ 16.716862 ],
#        [ 17.090094 ],
#        [ 17.71882  ],
#        [ 18.607128 ],
#        [ 19.432583 ],
#        [ 20.072548 ],
#        [ 20.514442 ],
#        [ 20.674461 ],
#        [ 20.519365 ],
#        [ 20.139357 ],
#        [ 19.667936 ],
#        [ 19.095678 ],
#        [ 18.588533 ],
#        [ 18.284756 ],
#        [ 18.23386  ],
#        [ 18.528078 ],
#        [ 19.036316 ],
#        [ 19.561121 ],
#        [ 19.995722 ],
#        [ 20.28017  ],
#        [ 20.44265  ],
#        [ 20.507547 ],
#        [ 20.571438 ],
#        [ 20.64112  ],
#        [ 20.70342  ],
#        [ 20.691956 ],
#        [ 20.646616 ],
#        [ 20.77564  ],
#        [ 21.278921 ],
#        [ 22.175516 ],
#        [ 23.169289 ],
#        [ 24.28754  ],
#        [ 24.763668 ],
#        [ 24.07407  ],
#        [ 22.657764 ],
#        [ 21.00654  ],
#        [ 19.692991 ],
#        [ 18.886894 ],
#        [ 18.621458 ],
#        [ 18.832838 ],
#        [ 19.316927 ],
#        [ 19.823435 ],
#        [ 20.224905 ],
#        [ 20.280571 ],
#        [ 20.084024 ],
#        [ 19.752626 ],
#        [ 19.369146 ],
#        [ 19.00657  ],
#        [ 18.670214 ],
#        [ 18.361027 ],
#        [ 18.006374 ],
#        [ 17.633226 ],
#        [ 17.251944 ],
#        [ 17.061577 ],
#        [ 17.027302 ],
#        [ 17.087307 ],
#        [ 17.130108 ],
#        [ 17.132994 ],
#        [ 17.1023   ],
#        [ 17.171642 ],
#        [ 17.386879 ],
#        [ 17.649843 ],
#        [ 17.82776  ],
#        [ 17.877125 ],
#        [ 17.891602 ],
#        [ 18.003447 ],
#        [ 18.225393 ],
#        [ 18.72862  ],
#        [ 19.365644 ],
#        [ 19.79424  ],
#        [ 20.065685 ],
#        [ 20.005707 ],
#        [ 19.796635 ],
#        [ 19.550488 ],
#        [ 19.331657 ],
#        [ 19.134586 ],
#        [ 18.90553  ],
#        [ 18.560125 ],
#        [ 17.907375 ],
#        [ 17.249563 ],
#        [ 16.840174 ],
#        [ 16.69909  ],
#        [ 16.751356 ],
#        [ 16.909399 ],
#        [ 17.135307 ],
#        [ 17.486452 ],
#        [ 17.884655 ],
#        [ 18.19187  ],
#        [ 18.373554 ],
#        [ 18.41689  ],
#        [ 18.31466  ],
#        [ 18.126595 ],
#        [ 17.90973  ],
#        [ 17.668636 ],
#        [ 17.440178 ],
#        [ 17.256496 ],
#        [ 17.190939 ],
#        [ 17.224983 ],
#        [ 17.309572 ],
#        [ 17.39495  ],
#        [ 17.459036 ],
#        [ 17.533508 ],
#        [ 17.608364 ],
#        [ 17.654308 ],
#        [ 17.641863 ],
#        [ 17.589937 ],
#        [ 17.551382 ],
#        [ 17.591625 ],
#        [ 17.734278 ],
#        [ 17.947664 ],
#        [ 18.132961 ],
#        [ 18.241526 ],
#        [ 18.278238 ],
#        [ 18.261583 ],
#        [ 18.199926 ],
#        [ 18.094057 ],
#        [ 18.006577 ],
#        [ 18.01871  ],
#        [ 18.056585 ],
#        [ 18.115322 ],
#        [ 18.183865 ],
#        [ 18.248901 ],
#        [ 18.302269 ],
#        [ 18.411219 ],
#        [ 18.579842 ],
#        [ 18.73771  ],
#        [ 18.937574 ],
#        [ 19.301003 ],
#        [ 19.687298 ],
#        [ 19.942017 ],
#        [ 20.047087 ],
#        [ 19.984385 ],
#        [ 19.837976 ],
#        [ 19.644157 ],
#        [ 19.482168 ],
#        [ 19.402437 ],
#        [ 19.377045 ],
#        [ 19.40057  ],
#        [ 19.447624 ],
#        [ 19.501842 ],
#        [ 19.580181 ],
#        [ 19.650576 ],
#        [ 19.670511 ],
#        [ 19.622    ],
#        [ 19.50729  ],
#        [ 19.3107   ],
#        [ 19.058828 ],
#        [ 18.772577 ],
#        [ 18.505846 ],
#        [ 18.315327 ],
#        [ 18.21671  ],
#        [ 18.191996 ],
#        [ 18.219799 ],
#        [ 18.270311 ],
#        [ 18.328358 ],
#        [ 18.448235 ],
#        [ 18.54497  ],
#        [ 18.59889  ],
#        [ 18.621733 ],
#        [ 18.612125 ],
#        [ 18.576807 ],
#        [ 18.522066 ],
#        [ 18.397934 ],
#        [ 18.24151  ],
#        [ 18.089115 ],
#        [ 17.91922  ],
#        [ 17.67737  ],
#        [ 17.486595 ],
#        [ 17.366432 ],
#        [ 17.285036 ],
#        [ 17.228657 ],
#        [ 17.198101 ],
#        [ 17.222551 ],
#        [ 17.278908 ],
#        [ 17.328157 ],
#        [ 17.34856  ],
#        [ 17.344357 ],
#        [ 17.304695 ],
#        [ 17.227386 ],
#        [ 17.106014 ],
#        [ 16.91976  ],
#        [ 16.731936 ],
#        [ 16.567347 ],
#        [ 16.472692 ],
#        [ 16.430359 ],
#        [ 16.41475  ],
#        [ 16.352718 ],
#        [ 16.268768 ],
#        [ 16.178438 ],
#        [ 16.103403 ],
#        [ 16.085995 ],
#        [ 16.113297 ],
#        [ 16.092178 ],
#        [ 16.034948 ],
#        [ 15.956274 ],
#        [ 15.838396 ],
#        [ 15.671214 ],
#        [ 15.42442  ],
#        [ 15.192726 ],
#        [ 15.009501 ],
#        [ 14.808414 ],
#        [ 14.618704 ],
#        [ 14.412946 ],
#        [ 14.141224 ],
#        [ 13.964729 ],
#        [ 13.9774685],
#        [ 14.121925 ],
#        [ 14.344723 ],
#        [ 14.542382 ],
#        [ 14.679633 ],
#        [ 14.789627 ],
#        [ 14.866257 ],
#        [ 14.890565 ],
#        [ 14.8206215],
#        [ 14.68726  ],
#        [ 14.5379925],
#        [ 14.406991 ],
#        [ 14.286873 ],
#        [ 14.187638 ],
#        [ 14.146626 ],
#        [ 14.1222   ],
#        [ 14.0518265],
#        [ 13.954134 ],
#        [ 13.845624 ],
#        [ 13.758745 ],
#        [ 13.693498 ],
#        [ 13.690164 ],
#        [ 13.827813 ],
#        [ 14.050658 ],
#        [ 14.265433 ],
#        [ 14.447549 ],
#        [ 14.604409 ],
#        [ 14.883604 ],
#        [ 15.428565 ],
#        [ 16.009306 ],
#        [ 16.478966 ],
#        [ 16.735992 ],
#        [ 16.843214 ],
#        [ 16.860565 ],
#        [ 16.857351 ],
#        [ 16.762796 ],
#        [ 16.614243 ],
#        [ 16.44814  ],
#        [ 16.2862   ],
#        [ 16.182356 ],
#        [ 16.114458 ],
#        [ 16.149656 ],
#        [ 16.260992 ],
#        [ 16.422194 ],
#        [ 16.61485  ],
#        [ 16.837074 ],
#        [ 17.028936 ],
#        [ 17.174603 ],
#        [ 17.24641  ],
#        [ 17.245272 ],
#        [ 17.197628 ],
#        [ 17.125315 ],
#        [ 17.053535 ],
#        [ 16.987598 ],
#        [ 16.944515 ],
#        [ 16.94462  ],
#        [ 16.979893 ],
#        [ 17.042658 ],
#        [ 17.148642 ],
#        [ 17.312653 ],
#        [ 17.49096  ],
#        [ 17.649733 ],
#        [ 17.7824   ],
#        [ 17.87079  ],
#        [ 17.867935 ],
#        [ 17.819859 ],
#        [ 17.768549 ],
#        [ 17.737816 ],
#        [ 17.715364 ],
#        [ 17.900293 ],
#        [ 18.245558 ],
#        [ 18.640018 ],
#        [ 18.964344 ],
#        [ 19.187708 ],
#        [ 19.304564 ],
#        [ 19.297474 ],
#        [ 19.2309   ],
#        [ 19.142246 ],
#        [ 19.118692 ],
#        [ 19.159155 ],
#        [ 19.291817 ],
#        [ 19.590992 ],
#        [ 20.088484 ],
#        [ 20.716894 ],
#        [ 21.517336 ],
#        [ 22.545584 ],
#        [ 23.669188 ],
#        [ 24.588163 ],
#        [ 25.258963 ],
#        [ 25.711138 ],
#        [ 25.888807 ],
#        [ 25.585983 ],
#        [ 25.06924  ],
#        [ 24.730238 ],
#        [ 24.904146 ],
#        [ 25.717022 ],
#        [ 27.492064 ],
#        [ 29.796524 ],
#        [ 32.806026 ],
#        [ 37.30671  ],
#        [ 42.538876 ],
#        [ 45.92022  ],
#        [ 48.20543  ],
#        [ 49.564556 ],
#        [ 50.15164  ],
#        [ 50.09475  ],
#        [ 49.802235 ],
#        [ 50.606205 ],
#        [ 52.187    ],
#        [ 53.80905  ],
#        [ 55.17291  ],
#        [ 56.166847 ],
#        [ 57.05501  ],
#        [ 57.73737  ],
#        [ 57.918808 ],
#        [ 57.746994 ],
#        [ 57.176804 ],
#        [ 55.881237 ],
#        [ 54.20612  ],
#        [ 52.657524 ],
#        [ 51.272976 ],
#        [ 50.04292  ],
#        [ 49.313908 ],
#        [ 48.981236 ],
#        [ 48.94177  ],
#        [ 49.073196 ],
#        [ 49.60966  ],
#        [ 50.879185 ],
#        [ 52.2574   ],
#        [ 53.543537 ],
#        [ 54.516495 ],
#        [ 55.05323  ],
#        [ 55.48304  ],
#        [ 55.593193 ],
#        [ 55.572502 ],
#        [ 55.347015 ],
#        [ 55.027355 ],
#        [ 54.706795 ],
#        [ 54.631382 ],
#        [ 54.77972  ],
#        [ 55.386696 ],
#        [ 57.409546 ],
#        [ 61.341232 ],
#        [ 65.98062  ],
#        [ 71.46403  ],
#        [ 76.56467  ],
#        [ 80.5699   ],
#        [ 83.470825 ],
#        [ 87.360016 ],
#        [ 91.67378  ],
#        [ 95.96925  ],
#        [ 99.14233  ],
#        [100.57878  ],
#        [100.51087  ],
#        [ 99.33435  ],
#        [ 97.7227   ],
#        [ 96.05701  ],
#        [ 94.926476 ],
#        [ 94.44776  ],
#        [ 94.69367  ],
#        [ 95.06218  ],
#        [ 95.36863  ],
#        [ 96.4127   ],
#        [101.99497  ],
#        [110.54739  ],
#        [123.4086   ],
#        [139.90573  ],
#        [157.47234  ],
#        [173.8223   ],
#        [184.68065  ],
#        [187.67296  ],
#        [184.23485  ],
#        [179.00703  ],
#        [177.49692  ],
#        [184.68959  ],
#        [197.76802  ],
#        [211.15343  ],
#        [221.80083  ],
#        [228.64992  ],
#        [234.63318  ],
#        [240.4241   ],
#        [247.56248  ],
#        [254.14856  ],
#        [259.47955  ],
#        [265.7594   ],
#        [279.8166   ],
#        [299.0923   ],
#        [326.78268  ],
#        [356.22473  ],
#        [375.52036  ],
#        [383.20862  ],
#        [383.25995  ],
#        [380.62906  ],
#        [376.67615  ],
#        [372.5535   ],
#        [367.67587  ],
#        [359.90726  ],
#        [350.92978  ],
#        [343.66162  ],
#        [336.83206  ],
#        [328.26193  ],
#        [315.25613  ],
#        [303.33768  ],
#        [299.74442  ],
#        [300.4221   ],
#        [301.68515  ],
#        [299.5525   ],
#        [296.35715  ],
#        [292.788    ],
#        [288.315    ],
#        [283.0893   ],
#        [278.31104  ],
#        [271.49597  ],
#        [264.3984   ],
#        [257.24097  ],
#        [247.57652  ],
#        [234.67818  ],
#        [225.48277  ],
#        [218.94518  ],
#        [213.41953  ],
#        [205.19263  ],
#        [193.70897  ],
#        [185.99364  ],
#        [188.72574  ],
#        [195.20474  ],
#        [205.02835  ],
#        [214.5105   ]], dtype=float32)

# %%
#Predict Next Day
real_data = [model_inputs[len(model_inputs)+1-prediction_days:len(model_inputs+1),0]]
real_data = np.array(real_data)
real_data = np.reshape(real_data,(real_data.shape[0],real_data.shape[1],1))

prediction = model.predict(real_data)
prediction = scaler.inverse_transform(prediction)
print(f"Prediction: {prediction}")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 60, 1) for input Tensor("lstm_3_input:0", shape=(None, 60, 1), dtype=float32), but it was called on an input with incompatible shape (None, 59, 1).
# Prediction: [[2665.0974]]
